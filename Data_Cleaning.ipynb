# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/cleaning/fresno.csv')
df
# Out:
#     ObjectID                  Park Name  \
# 0          1                   Koligian
# 1          2                      Lions
# 2          3                Rotary East
# 3          4                      Logan
# 4          5                 University
# ..       ...                        ...
# 76       875                 Palm Lakes
# 77       881           Milburn Overlook
# 78       883                  Rabe Park
# 79      1682  Rotary West (B/E) (Basin)
# 80      1683                     Sunset
#
#                                              Location  \
# 0                       5165 W. Alluvial, Fresno, CA
# 1                  4650 N. Marks, Fresno, CA  93705
# 2                           6464 N. Cedar, Fresno, CA
# 3                5450 N. Santa Fe, Fresno, CA  93722
# 4   4085 S. Angus, Joaquin and Angus Avenues, Fres...
# ..                                                ...
# 76                                         3232 Peach
# ...

# %%
df = df.drop_duplicates()
df.head()
# Out:
#    ObjectID    Park Name                                           Location  \
# 0         1     Koligian                      5165 W. Alluvial, Fresno, CA
# 1         2        Lions                 4650 N. Marks, Fresno, CA  93705
# 2         3  Rotary East                          6464 N. Cedar, Fresno, CA
# 3         4        Logan               5450 N. Santa Fe, Fresno, CA  93722
# 4         5   University  4085 S. Angus, Joaquin and Angus Avenues, Fres...
#
#                                           Directions  \
# 0  (Neighborhood Park), 7.06 Acres,  488-1502\r\n...
# 1  (Neighborhood Park), 9.02 Acres  (559) 488-150...
# 2  (Neighborhood Park), 5.0 Acres  (559) 621-6720...
# 3  (Neighborhood Park), 9.0 Acres  (559) 488-1502...
# 4  This park is located South of Ashlan and west ...
#
#                                           Activities Park Type  \
# 0  Barbecues, Baseball/Softball Fields, Basketbal...     npark
# ...

# %%
columns_to_drop = ['Location', 'Directions', "Activities", "Park Type", "Council District", "District", "Council Person", "Layer Refresh Date", "Shape__Area", 'Shape__Length' ]
df = df.drop(columns=columns_to_drop)
df.head()
# Out:
#    ObjectID    Park Name
# 0         1     Koligian
# 1         2        Lions
# 2         3  Rotary East
# 3         4        Logan
# 4         5   University

# %%
df['City'] = 'Fresno'
df
# Out:
#     ObjectID                  Park Name    City
# 0          1                   Koligian  Fresno
# 1          2                      Lions  Fresno
# 2          3                Rotary East  Fresno
# 3          4                      Logan  Fresno
# 4          5                 University  Fresno
# ..       ...                        ...     ...
# 76       875                 Palm Lakes  Fresno
# 77       881           Milburn Overlook  Fresno
# 78       883                  Rabe Park  Fresno
# 79      1682  Rotary West (B/E) (Basin)  Fresno
# 80      1683                     Sunset  Fresno
#
# [81 rows x 3 columns]

# %%
new_column_name = 'Name'
df = df.rename(columns={'Park Name': new_column_name})
df.head()
# Out:
#    ObjectID         Name    City
# 0         1     Koligian  Fresno
# 1         2        Lions  Fresno
# 2         3  Rotary East  Fresno
# 3         4        Logan  Fresno
# 4         5   University  Fresno

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
csv_path = '/content/drive/My Drive/fresno.csv'  # Specify the path to save the CSV file in your Google Drive
df.to_csv(csv_path, index=False)

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/cleaning/nyc.csv")

# %%
df1.shape
# Out:
# (2047, 35)

# %%
column_to_keep = 'NAME311'
df1 = df1[[column_to_keep]]
df1
# Out:
#                               NAME311
# 0                    Sunset Cove Park
# 1     Grand Central Parkway Extension
# 2                Challenge Playground
# 3                     Eastern Parkway
# 4                Cross Island Parkway
# ...                               ...
# 2042               Broad Channel Park
# 2043                      The Battery
# 2044                Park Avenue Malls
# 2045               Francis Lewis Park
# 2046                      Kaiser Park
#
# [2047 rows x 1 columns]

# %%
df1 = df1.drop_duplicates()
df1.head()
# Out:
#                            NAME311
# 0                 Sunset Cove Park
# 1  Grand Central Parkway Extension
# 2             Challenge Playground
# 3                  Eastern Parkway
# 4             Cross Island Parkway

# %%
df1['City'] = 'New York City'
df1
# Out:
# <ipython-input-29-dab13339ed0e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['City'] = 'New York City'
#                               NAME311           City
# 0                    Sunset Cove Park  New York City
# 1     Grand Central Parkway Extension  New York City
# 2                Challenge Playground  New York City
# 3                     Eastern Parkway  New York City
# 4                Cross Island Parkway  New York City
# ...                               ...            ...
# 2040                P.S. 29 Ballfield  New York City
# 2042               Broad Channel Park  New York City
# 2043                      The Battery  New York City
# 2045               Francis Lewis Park  New York City
# ...

# %%
new_column_name = 'Name'
df1 = df1.rename(columns={'NAME311': new_column_name})
df1.head()
# Out:
#                               Name           City
# 0                 Sunset Cove Park  New York City
# 1  Grand Central Parkway Extension  New York City
# 2             Challenge Playground  New York City
# 3                  Eastern Parkway  New York City
# 4             Cross Island Parkway  New York City

# %%
csv_path = '/content/drive/My Drive/nyc.csv'  # Specify the path to save the CSV file in your Google Drive
df1.to_csv(csv_path, index=False)

# %%
df2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/cleaning/Syracuse_Athletic_Courts.csv")
df2.head()
# Out:
#               X             Y           PARK  COURT_TYPE  \
# 0 -8.478275e+06  5.319682e+06  Barker Square  Basketball
# 1 -8.473287e+06  5.316343e+06     Barry Park  Basketball
# 2 -8.473289e+06  5.316309e+06     Barry Park  Basketball
# 3 -8.473343e+06  5.316567e+06     Barry Park      Tennis
# 4 -8.480773e+06  5.318274e+06    Burnet Park  Basketball
#
#   COURT_SIZE___QUANTITY IMPROV__YEAR        LAT       LONG  ObjectId
# 0        Half Court (2)         2021  43.050634 -76.161638         1
# 1            Full Court         2022  43.028710 -76.116828         2
# 2        Half Court (2)          NaN  43.028485 -76.116854         3
# 3       Lined Court (2)         2021  43.030181 -76.117332         4
# 4            Full Court          NaN  43.041390 -76.184078         5

# %%
column_to_keep = 'PARK'
df2 = df2[[column_to_keep]]

# %%
df2 = df2.drop_duplicates()
df2.head()
# Out:
#                              PARK
# 0                   Barker Square
# 1                      Barry Park
# 4                     Burnet Park
# 6  Cannon Street Community Center
# 7                 Clinton Playlot

# %%
new_column_name = 'Name'
df2 = df2.rename(columns={'PARK': new_column_name})
df2.head()
# Out:
#                              Name
# 0                   Barker Square
# 1                      Barry Park
# 4                     Burnet Park
# 6  Cannon Street Community Center
# 7                 Clinton Playlot

# %%
df2['City'] = 'Syracuse'
df2
# Out:
#                               Name      City
# 0                    Barker Square  Syracuse
# 1                       Barry Park  Syracuse
# 4                      Burnet Park  Syracuse
# 6   Cannon Street Community Center  Syracuse
# 7                  Clinton Playlot  Syracuse
# 8               Comfort Tyler Park  Syracuse
# 10                     Dunbar Park  Syracuse
# 13           Eastwood Heights Park  Syracuse
# 14              Homer-Wheaton Park  Syracuse
# 16                 Huntington Park  Syracuse
# 17                       Kirk Park  Syracuse
# 21                      Lewis Park  Syracuse
# 22              Libba-Cotton Grove  Syracuse
# 23                    Lincoln Park  Syracuse
# 25                  McChesney Park  Syracuse
# 27                   McKinley Park  Syracuse
# 29                    Meachem Park  Syracuse
# 30               Nottingham Courts  Syracuse
# 31             Onondaga Park Upper  Syracuse
# 33             Ormand Spencer Park  Syracuse
# ...

# %%
csv_path = '/content/drive/My Drive/syracuse.csv'  # Specify the path to save the CSV file in your Google Drive
df2.to_csv(csv_path, index=False)

# %%
df.head()
# Out:
#    ObjectID         Name    City
# 0         1     Koligian  Fresno
# 1         2        Lions  Fresno
# 2         3  Rotary East  Fresno
# 3         4        Logan  Fresno
# 4         5   University  Fresno

# %%
column_to_drop = 'ObjectID'
df = df.drop(columns=column_to_drop)

# %%
df.head()
# Out:
#           Name    City
# 0     Koligian  Fresno
# 1        Lions  Fresno
# 2  Rotary East  Fresno
# 3        Logan  Fresno
# 4   University  Fresno

# %%
df1.head()
# Out:
#                               Name           City
# 0                 Sunset Cove Park  New York City
# 1  Grand Central Parkway Extension  New York City
# 2             Challenge Playground  New York City
# 3                  Eastern Parkway  New York City
# 4             Cross Island Parkway  New York City

# %%
df2.head()
# Out:
#                              Name      City
# 0                   Barker Square  Syracuse
# 1                      Barry Park  Syracuse
# 4                     Burnet Park  Syracuse
# 6  Cannon Street Community Center  Syracuse
# 7                 Clinton Playlot  Syracuse

# %%
maindf = pd.concat([df, df1, df2], axis=0)
maindf.head()
# Out:
#           Name    City
# 0     Koligian  Fresno
# 1        Lions  Fresno
# 2  Rotary East  Fresno
# 3        Logan  Fresno
# 4   University  Fresno

# %%
maindf
# Out:
#                       Name      City
# 0                 Koligian    Fresno
# 1                    Lions    Fresno
# 2              Rotary East    Fresno
# 3                    Logan    Fresno
# 4               University    Fresno
# ..                     ...       ...
# 47           Thornden Park  Syracuse
# 49          Wadsworth Park  Syracuse
# 50  Washington Square Park  Syracuse
# 52       Westmoreland Park  Syracuse
# 53             Wilson Park  Syracuse
#
# [1960 rows x 2 columns]

# %%
csv_path = '/content/drive/My Drive/park_data.csv'  # Specify the path to save the CSV file in your Google Drive
maindf.to_csv(csv_path, index=False)
